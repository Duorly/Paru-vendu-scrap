# %%
from enum import Enum
from sqlalchemy import Column, Integer, String, create_engine, DateTime, Boolean, ForeignKey, select
from sqlalchemy.orm import declarative_base, mapped_column, Mapped, relationship, sessionmaker
from sqlalchemy.exc import SQLAlchemyError
from typing import Optional, Dict, Any, List
from datetime import datetime

DATABASE_URL = "mysql+pymysql://root:@127.0.0.1:3306/paruvendu"
engine = create_engine(DATABASE_URL, echo=True)

Base = declarative_base()

class AnnouncementType(Enum):
    MAISON = 1
    APPARTEMENT = 2

class AnnouncerType(Enum):
    PARTICULIER = 1
    PROFFESSIONELLE = 2
    NB = 2

class Agency(Base):
    __tablename__ = 'announcer'
    id = Column(Integer, primary_key=True)
    name = Column(String(100), nullable=True)
    address = Column(String(100), nullable=True)
    slogan = Column(String(200), nullable=True)
    description = Column(String(1000), nullable=True)
    telephone = Column(String(15), nullable=True)
    yearMember = Column(String(15), nullable=True)
    announcements: Mapped[List["Announcement"]] = relationship(
        "Announcement",
        back_populates="agency",
        cascade="all, delete-orphan",
        lazy="select"
    )

class Announcement(Base):
    __tablename__ = 'announcements'
    id = Column(Integer, primary_key=True)
    ref = Column(String(20), nullable=True)
    title = Column(String(50), nullable=True)
    description = Column(String(1000), nullable=True)
    price = Column(Integer, nullable=True)
    price_per_meter = Column(Integer, nullable=True)
    publish_at = Column(DateTime, nullable=True)
    exclusive = Column(Boolean, nullable=True)
    updated_at = Column(DateTime, nullable=True)
    dpe = Column(String(1), nullable=True, info={'comment': 'DPE rating A to G'})
    url = Column(String(200), nullable=True)
    type = Column(Integer, nullable=True)
    agency_id = mapped_column(ForeignKey("announcer.id"))
    agency: Mapped[Agency] = relationship(
        "Agency",
        back_populates="announcements",
        lazy="joined"
    )

class Caracteristic(Base):
    __tablename__ = 'estate'
    id = Column(Integer, primary_key=True)
    announcement_id = mapped_column(ForeignKey("announcements.id"))
    announcement: Mapped[Announcement] = relationship()
    nb_rooms = Column(Integer, nullable=True)
    nb_bedrooms = Column(Integer, nullable=True)
    location = Column(String(50), nullable=True, info={'comment': 'Location'})
    parking_garage = Column(Boolean, nullable=True)
    garden = Column(Boolean, nullable=True)
    balcony_terrace = Column(Boolean, nullable=True)
    annexes = Column(String(10), nullable=True)
    access = Column(String(50), nullable=True)
    arrangement = Column(String(50), nullable=True)
    dependence = Column(String(50), nullable=True)
    outside = Column(String(50), nullable=True)
    connectivity_index = Column(Integer, nullable=True)
    fiber_eligibility_rate = Column(Integer, nullable=True)
    general_information = Column(String(200), nullable=True)
    surface = Column(String(200), nullable=True)
    agencement = Column(String(200), nullable=True)

def init_db():
    Base.metadata.create_all(engine)

def drop_db():
    Base.metadata.drop_all(engine)

def reset_db():
    drop_db()
    init_db()
    print("Database reset completed.")

# Initialiser la base de données (créer les tables)
reset_db()
# Out:
# 2025-11-26 16:58:53,414 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-11-26 16:58:53,416 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-26 16:58:53,418 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-11-26 16:58:53,419 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-26 16:58:53,421 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-11-26 16:58:53,422 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-26 16:58:53,424 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:53,424 INFO sqlalchemy.engine.Engine DESCRIBE `paruvendu`.`announcer`
# 2025-11-26 16:58:53,426 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-26 16:58:53,458 INFO sqlalchemy.engine.Engine DESCRIBE `paruvendu`.`announcements`
# 2025-11-26 16:58:53,459 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-26 16:58:53,469 INFO sqlalchemy.engine.Engine DESCRIBE `paruvendu`.`estate`
# 2025-11-26 16:58:53,470 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-26 16:58:53,480 INFO sqlalchemy.engine.Engine
# DROP TABLE estate
# 2025-11-26 16:58:53,481 INFO sqlalchemy.engine.Engine [no key 0.00106s] {}
# 2025-11-26 16:58:53,497 INFO sqlalchemy.engine.Engine
# DROP TABLE announcements
# 2025-11-26 16:58:53,499 INFO sqlalchemy.engine.Engine [no key 0.00198s] {}
# 2025-11-26 16:58:53,510 INFO sqlalchemy.engine.Engine
# DROP TABLE announcer
# 2025-11-26 16:58:53,511 INFO sqlalchemy.engine.Engine [no key 0.00143s] {}
# 2025-11-26 16:58:53,523 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:53,525 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:53,526 INFO sqlalchemy.engine.Engine DESCRIBE `paruvendu`.`announcer`
# 2025-11-26 16:58:53,527 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-26 16:58:53,537 INFO sqlalchemy.engine.Engine DESCRIBE `paruvendu`.`announcements`
# 2025-11-26 16:58:53,538 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-26 16:58:53,548 INFO sqlalchemy.engine.Engine DESCRIBE `paruvendu`.`estate`
# 2025-11-26 16:58:53,549 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-26 16:58:53,559 INFO sqlalchemy.engine.Engine
# CREATE TABLE announcer (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	name VARCHAR(100),
# 	address VARCHAR(100),
# 	slogan VARCHAR(200),
# 	description VARCHAR(1000),
# 	telephone VARCHAR(15),
# 	`yearMember` VARCHAR(15),
# 	PRIMARY KEY (id)
# )
#
#
# 2025-11-26 16:58:53,560 INFO sqlalchemy.engine.Engine [no key 0.00158s] {}
# 2025-11-26 16:58:53,578 INFO sqlalchemy.engine.Engine
# CREATE TABLE announcements (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	ref VARCHAR(20),
# 	title VARCHAR(50),
# 	description VARCHAR(1000),
# 	price INTEGER,
# 	price_per_meter INTEGER,
# 	publish_at DATETIME,
# 	exclusive BOOL,
# 	updated_at DATETIME,
# 	dpe VARCHAR(1),
# 	url VARCHAR(200),
# 	type INTEGER,
# 	agency_id INTEGER,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(agency_id) REFERENCES announcer (id)
# )
#
#
# 2025-11-26 16:58:53,579 INFO sqlalchemy.engine.Engine [no key 0.00144s] {}
# 2025-11-26 16:58:53,624 INFO sqlalchemy.engine.Engine
# CREATE TABLE estate (
# 	id INTEGER NOT NULL AUTO_INCREMENT,
# 	announcement_id INTEGER,
# 	nb_rooms INTEGER,
# 	nb_bedrooms INTEGER,
# 	location VARCHAR(50),
# 	parking_garage BOOL,
# 	garden BOOL,
# 	balcony_terrace BOOL,
# 	annexes VARCHAR(10),
# 	access VARCHAR(50),
# 	arrangement VARCHAR(50),
# 	dependence VARCHAR(50),
# 	outside VARCHAR(50),
# 	connectivity_index INTEGER,
# 	fiber_eligibility_rate INTEGER,
# 	general_information VARCHAR(200),
# 	surface VARCHAR(200),
# 	agencement VARCHAR(200),
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(announcement_id) REFERENCES announcements (id)
# )
#
#
# 2025-11-26 16:58:53,626 INFO sqlalchemy.engine.Engine [no key 0.00195s] {}
# 2025-11-26 16:58:53,669 INFO sqlalchemy.engine.Engine COMMIT
# Database reset completed.

# %%
SessionLocal = sessionmaker(bind=engine, autoflush=False, autocommit=False)

def create_announcement(
    session,
    announcement_data: Dict[str, Any],
    announcer_data: Dict[str, Any],
    estate_data: Optional[Dict[str, Any]] = None,
    *,
    dedupe_agency_by: Optional[list] = None
):
    """
    Crée une annonce, associe une agence (sans la dupliquer) et crée les caractéristiques optionnelles.

    - session: SQLAlchemy session (ex: SessionLocal()).
    - announcement_data: dict contenant les champs de Announcement (ref, title, price, publish_at, url, type, etc.)
    - announcer_data: dict avec les champs de Agency (name, telephone, address, slogan?, description?)
    - estate_data: dict optionnel pour Caracteristic.
    - dedupe_agency_by: liste des champs sur lesquels dédupliquer l'agence (par défaut ['name', 'telephone']).

    Retourne l'objet Announcement (attaché à la session) après commit.
    """
    if dedupe_agency_by is None:
        dedupe_agency_by = ["name"]

    try:
        # Transaction
        with session.begin():
            # 1) chercher l'agence existante en se basant sur les champs fournis
            agency_filters = {}
            for key in dedupe_agency_by:
                if key in announcer_data and announcer_data[key] is not None:
                    agency_filters[key] = announcer_data[key]

            agency = None
            if agency_filters:
                stmt = select(Agency).filter_by(**agency_filters)
                agency = session.execute(stmt).scalars().first()

            # 2) si pas trouvée, créer l'agence (en utilisant seulement les champs valides)
            if agency is None:
                # Construire un dict contenant uniquement les colonnes existantes sur Agency
                allowed_agency_fields = {
                    "name", "address", "slogan", "description", "telephone"
                }
                agency_kwargs = {k: announcer_data.get(k) for k in allowed_agency_fields if k in announcer_data}
                agency = Agency(**agency_kwargs)
                session.add(agency)
                # flush pour obtenir agency.id si nécessaire plus loin
                session.flush()

            # 3) vérifier si l'annonce existe déjà (optionnel) -> éviter duplication si ref unique
            announcement = None
            ref = announcement_data.get("ref")
            if ref:
                stmt = select(Announcement).filter_by(ref=ref, agency_id=agency.id)
                announcement = session.execute(stmt).scalars().first()

            # 4) créer ou mettre à jour l'annonce
            allowed_announcement_fields = {
                "ref", "title", "description", "price", "price_per_meter", "publish_at", "exclusive",
                "updated_at", "dpe", "url", "type"
            }
            ann_kwargs = {k: announcement_data.get(k) for k in allowed_announcement_fields if k in announcement_data}

            # si l'utilisateur passe un Enum AnnouncementType, convertir en int
            if "type" in ann_kwargs and ann_kwargs["type"] is not None:
                t = ann_kwargs["type"]
                # supporte int, Enum, ou string représentant un int
                if hasattr(t, "value"):
                    ann_kwargs["type"] = int(t.value)
                else:
                    try:
                        ann_kwargs["type"] = int(t)
                    except Exception:
                        # laisse tel quel (DB attend un int mais on assume que l'appelant envoie correct)
                        pass

            if announcement is None:
                announcement = Announcement(**ann_kwargs)
                # fixer la relation vers l'agence
                announcement.agency = agency
                session.add(announcement)
                session.flush()  # pour obtenir announcement.id si besoin
            else:
                # si déjà existante, on met à jour les champs fournis
                for k, v in ann_kwargs.items():
                    setattr(announcement, k, v)

            # 5) créer les caractéristiques si fournies
            if estate_data is not None:
                # vérifier s'il existe déjà une ligne de caractéristique pour cette annonce
                stmt = select(Caracteristic).filter_by(announcement_id=announcement.id)
                existing_car = session.execute(stmt).scalars().first()
                allowed_car_fields = {
                    "parking_garage", "garden","nb_rooms", "nb_bedrooms", "balcony_terrace", "annexes", "access",
                    "arrangement", "dependence", "outside", "connectivity_index","location",
                    "fiber_eligibility_rate", "general_information", "agencement", "surface"
                }
                car_kwargs = {k: estate_data.get(k) for k in allowed_car_fields if k in estate_data}

                if existing_car is None:
                    car_kwargs["announcement_id"] = announcement.id
                    caracteristic = Caracteristic(**car_kwargs)
                    session.add(caracteristic)
                else:
                    for k, v in car_kwargs.items():
                        setattr(existing_car, k, v)

            # commit fait automatiquement par session.begin() context manager
            # retourner l'annonce (attachée au session)
            return announcement

    except SQLAlchemyError as exc:
        # rollback implicite si exception dans session.begin()
        # relancer après log ou gestion si nécessaire
        raise


# --- Exemple d'utilisation ---
# if __name__ == "__main__":
#     s = SessionLocal()

#     agency_payload = {
#         "name": "Agence Dupont",
#         "address": "1 rue de Paris, 75001 Paris",
#         "telephone": "0123456789",
#         "yearMember": "2020",
#         "description": "Agence spécialisée dans les maisons familiales"
#     }

#     announcement_payload = {
#         "ref": "PV-2025-0001",
#         "title": "Maison familiale 4 pièces",
#         "description": "Belle maison avec jardin, proche écoles et commerces.",
    #     "price": 350000,
    #     "price_per_meter": 2500,
    #     "publish_at": datetime.now(),
    #     "exclusive": True,
    #     "updated_at": datetime.now(),
    #     "dpe": "B",
    #     "url": "https://paruvendu.example/annonce/1",
    #     "type": AnnouncementType.MAISON.value,  # int pour la DB
    # }

    # caracteristic_payload = {
    #     "nb_rooms": 5,
    #     "nb_bedrooms": 3,
    #     "location": "Paris 8ème",
    #     "parking_garage": True,
    #     "garden": False,
    #     "balcony_terrace": True,
    #     "annexes": "Cave",
    #     "access": "Digicode, Interphone",
    #     "arrangement": "Traversant",
    #     "outside": "Cour intérieure",
    #     "connectivity_index": 95,
    #     "fiber_eligibility_rate": 100,
    #     "general_information": "Proche métro et commerces"
    # }

    # ann = create_announcement(
    #     s,
    #     announcement_data=announcement_payload,
    #     announcer_data=agency_payload,
    #     estate_data=caracteristic_payload
    # )

    # print("Created announcement id:", ann.id)
    # s.close()

# %%
import pandas as pd
import ast
paruvendu_data = pd.read_csv("results.csv",  header=None)
paruvendu_data[1] = paruvendu_data[1].apply(ast.literal_eval)
df_dico = pd.json_normalize(paruvendu_data[1])
df_dico
# Out:
#                                 title                        location  \
# 0     Vente Appartement 1 pièce 28 m²                Paris 13 (75013)
# 1     Vente Appartement 1 pièce 28 m²           Aubervilliers (93300)
# 2    Vente Appartement 2 pièces 42 m²             Saint denis (93200)
# 3     Vente Appartement 1 pièce 24 m²   Carrieres sous poissy (78955)
# 4    Vente Appartement 2 pièces 52 m²     La garenne-colombes (92250)
# 5     Vente Appartement 1 pièce 30 m²   Carrieres sous poissy (78955)
# 6        Vente Maison 6 pièces 160 m²              Adainville (78113)
# 7        Vente Maison 8 pièces 190 m²         Poigny la foret (78125)
# 8                                                  Bennecourt (78270)
# 9        Vente Maison 5 pièces 163 m²               Bourdonne (78113)
# 10   Vente Appartement 3 pièces 60 m²                   Meaux (77100)
# 11       Vente Maison 5 pièces 115 m²        St cyr sur morin (77750)
# 12                                            Magny le hongre (77700)
# 13   Vente Appartement 5 pièces 85 m²                  Chessy (77700)
# 14   Vente Appartement 3 pièces 65 m²                   Meaux (77100)
# 15   Vente Appartement 3 pièces 62 m²                   Meaux (77100)
# 16       Vente Maison 5 pièces 137 m²               Etrepilly (77139)
# 17       Vente Maison 6 pièces 112 m²              Bassevelle (77750)
# 18       Vente Maison 5 pièces 155 m²  Couilly pont aux dames (77860)
# 19    Vente Appartement 1 pièce 24 m²                   Meaux (77100)
# 20  Vente Appartement 4 pièces 106 m²                   Meaux (77100)
# 21       Vente Maison 6 pièces 135 m²    St germain sur morin (77860)
# 22       Vente Maison 6 pièces 171 m²   Bailly romainvilliers (77700)
# 23       Vente Maison 5 pièces 100 m²                   Orsay (91400)
# 24    Vente Appartement 1 pièce 21 m²                  Grigny (91350)
# 25        Vente Maison 4 pièces 60 m²              Athis mons (91200)
# 26   Vente Appartement 2 pièces 48 m²                Paris 19 (75019)
# 27   Vente Appartement 3 pièces 84 m²                 Chelles (77500)
# 28   Vente Appartement 3 pièces 63 m²      Dammartin-en-goële (77230)
# 29       Vente Maison 6 pièces 190 m²               Corbreuse (91410)
# 30    Vente Appartement 1 pièce 22 m²       Brétigny-sur-orge (91220)
# 31                                             Bourg-la-reine (92340)
# 32   Vente Appartement 3 pièces 92 m²    La celle-saint-cloud (78170)
# 33       Vente Maison 7 pièces 115 m²                 Chelles (77500)
# 34   Vente Appartement 5 pièces 91 m²          Viry chatillon (91170)
# 35   Vente Appartement 4 pièces 85 m²          Viry chatillon (91170)
# 36  Vente Appartement 5 pièces 102 m²          Viry chatillon (91170)
# 37   Vente Appartement 3 pièces 60 m²          Viry chatillon (91170)
#
#                            descriptionTitle  \
# 0                 Description T1 à Paris 13
# 1            Description T1 à Aubervilliers
# 2              Description T2 à Saint denis
# 3    Description T1 à Carrieres sous poissy
# 4      Description T2 à La garenne-colombes
# 5    Description T1 à Carrieres sous poissy
# 6               Description T6 à Adainville
# 7          Description T8 à Poigny la foret
# 8
# 9                Description T5 à Bourdonne
# 10                   Description T3 à Meaux
# 11        Description T5 à St cyr sur morin
# 12
# 13                  Description T5 à Chessy
# 14                   Description T3 à Meaux
# 15                   Description T3 à Meaux
# 16               Description T5 à Etrepilly
# 17              Description T6 à Bassevelle
# 18  Description T5 à Couilly pont aux dames
# 19                   Description T1 à Meaux
# 20                   Description T4 à Meaux
# 21    Description T6 à St germain sur morin
# 22   Description T6 à Bailly romainvilliers
# 23                   Description T5 à Orsay
# 24                  Description T1 à Grigny
# 25              Description T4 à Athis mons
# 26                Description T2 à Paris 19
# 27                 Description T3 à Chelles
# 28      Description T3 à Dammartin-en-goële
# 29               Description T6 à Corbreuse
# 30       Description T1 à Brétigny-sur-orge
# 31
# 32    Description T3 à La celle-saint-cloud
# 33                 Description T7 à Chelles
# 34          Description T5 à Viry chatillon
# 35          Description T4 à Viry chatillon
# 36          Description T5 à Viry chatillon
# 37          Description T3 à Viry chatillon
#
#                                           description nbp surf     prix  \
# 0   Appartement 75013 - PARIS - BUTTE AUX CAILLES ...   1   28  240 750
# 1   Appartement 1 pièce Aubervilliers 27 m2 A vend...   1   28  135 000
# 2   Appartement Pierrefitte Sur Seine 2 pièces 42 ...   2   42  137 800
# 3   APPARTEMENT POISSY - 1 pièce(s) - 24.46m2 IDÉA...   1   24  123 000
# 4   Vente Appartemnt Au c?ur des vallées à proximi...   2   52  435 000
# 5   studio vendu loue Dans un quartier calme de Ca...   1   30  130 000
# 6   MAISON BEAU JARDIN PISCINE COUVERTE ET SOUS-SO...   6  160  415 000
# 7   Maison Poigny La Foret 8 pièce(s) 190 m2 Dans ...   8  190  598 000
# 8   EXCLUSIVITE - Propriété pleine de charme avec ...   8  208     None
# 9   Maison 5 pièce(s) 163 m2 Dans village entre Ga...   5  163  400 000
# 10  À vendre Bel appartement T3 avec balcon et vue...   3   60  164 000
# 11  maison Meulière à Saint Cyr sur Morin ADM IMMO...   5  115  260 000
# 12  Maison Familiale 6 pièces - 131 M2 ADM IMMOBIL...   6  131     None
# 13  appartement F5 avec magnifique terrasse ADM IM...   5   85  535 000
# 14  À vendre Appartement 3 pièces de 65 m2 Meaux (...   3   65  225 000
# 15  F3 avec grand balcon au dernier étage avec asc...   3   62  169 500
# 16  MAISON INDIVIDUELLE AVEC JARDIN ET SOUS-SOL EX...   5  137  310 000
# 17  propriété avec maison principale et seconde co...   6  112  210 000
# 18  maison de caractère à Couilly-Pont-Aux-Dames S...   5  155  470 000
# 19  Studio lumineux avec parking vendu loué en meu...   1   24  115 000
# 20  Appartement 4 pièces avec balcon, cave et gara...   4  106  298 000
# 21  Maison de 6 pièces dont 4 chambres avec un ter...   6  135  585 000
# 22  Maison T6 AVEC JARDIN À Vendre chez ADM IMMOBI...   6  171  475 000
# 23  Maison Orsay 5 pièce(s) 100 m2 L'agence immobi...   5  100  449 000
# 24  Investissement Locatif SÉCURISÉ - Studio 21 m²...   1   21   44 900
# 25  Maison Athis-mons 4 pièce(s) 60 m2 Votre agenc...   4   60  260 000
# 26  Appartement Paris 2 pièce(s) 48 m2 - CABINET M...   2   48  320 000
# 27  Vente Appartement 3 pièces iad France - Xueyu ...   3   84  270 000
# 28  Vente Duplex 3 pièces iad France - Mélanie Lou...   3   63  211 000
# 29  Vente Maison/villa 6 pièces iad France - Louis...   6  190  259 000
# 30  Vente Studio 1 pièce iad France - Julie BLOIS ...   1   22   97 000
# 31  Vente Maison/villa 7 pièces iad France - Léna ...   7  179     None
# 32  Vente Appartement 3 pièces iad France - Mary P...   3   92  295 000
# 33  Vente Maison traditionnelle 7 pièces iad Franc...   7  115  345 000
# 34  T5 Vu à couper le souffle bord de seine ! Roof...   5   91  464 000
# 35  T4 Lumineux Grande Terrasse Vu Seine Offrez-vo...   4   85  364 000
# 36  T5 Terrasse VU SEINE de 67 m2 ! Verdoyant Offr...   5  102  475 000
# 37  T3 Bord de Seine & bien agencer Offrez-vous un...   3   60  248 000
#
#                                  enseigneInfosvendeur  \
# 0                          EFFICITY Sukhanakova Elena
# 1                             L'ADRESSE AUBERVILLIERS
# 2                             L'ADRESSE AUBERVILLIERS
# 3                                      HAG IMMOBILIER
# 4                                            MAXIHOME
# 5                                      HAG IMMOBILIER
# 6                           STEPHAN CEREZO IMMOBILIER
# 7                           STEPHAN CEREZO IMMOBILIER
# 8
# 9                           STEPHAN CEREZO IMMOBILIER
# 10                                     ADM IMMOBILIER
# 11                                     ADM IMMOBILIER
# 12
# 13                                     ADM IMMOBILIER
# 14                                     ADM IMMOBILIER
# 15                                     ADM IMMOBILIER
# 16                                     ADM IMMOBILIER
# 17                                     ADM IMMOBILIER
# 18                                     ADM IMMOBILIER
# 19                                     ADM IMMOBILIER
# 20                                     ADM IMMOBILIER
# 21                                     ADM IMMOBILIER
# 22                                     ADM IMMOBILIER
# 23                                    L'ADRESSE ORSAY
# 24
# 25                               L ADRESSE ATHIS MONS
# 26                               L ADRESSE ATHIS MONS
# 27  iad France Agent Commercial immatriculé à CCI ...
# 28  iad France Agent Commercial immatriculé à CCI ...
# 29  iad France Agent Commercial immatriculé à CCI ...
# 30  iad France Agent Commercial immatriculé à CCI ...
# 31
# 32  iad France Agent Commercial immatriculé à CCI ...
# 33  iad France Agent Commercial immatriculé à CCI ...
# 34                      UTOPIA Paris - Bordeau - PACA
# 35                      UTOPIA Paris - Bordeau - PACA
# 36                      UTOPIA Paris - Bordeau - PACA
# 37                      UTOPIA Paris - Bordeau - PACA
#
#                                        agencement  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                     2 chambres
# 28                                     2 chambres
# 29                                     4 chambres
# 30
# 31                                       Cheminée
# 32  2 chambres,Type  cuisine : Cuisine américaine
# 33                                     4 chambres
# 34                                     4 chambres
# 35                                     3 chambres
# 36                                     4 chambres
# 37                                     2 chambres
#
#                                           general   annexe dependance  \
# 0                                             NaN      NaN        NaN
# 1                                             NaN      NaN        NaN
# 2                                             NaN      NaN        NaN
# 3                                             NaN      NaN        NaN
# 4                                             NaN      NaN        NaN
# 5                                             NaN      NaN        NaN
# 6                                             NaN      NaN        NaN
# 7                                             NaN      NaN        NaN
# 8                                             NaN      NaN        NaN
# 9                                             NaN      NaN        NaN
# 10                                            NaN      NaN        NaN
# 11                                            NaN      NaN        NaN
# 12                                            NaN      NaN        NaN
# 13                                            NaN      NaN        NaN
# 14                                            NaN      NaN        NaN
# 15                                            NaN      NaN        NaN
# 16                                            NaN      NaN        NaN
# 17                                            NaN      NaN        NaN
# 18                                            NaN      NaN        NaN
# 19                                            NaN      NaN        NaN
# 20                                            NaN      NaN        NaN
# 21                                            NaN      NaN        NaN
# 22                                            NaN      NaN        NaN
# 23                                            NaN      NaN        NaN
# 24                                            NaN      NaN        NaN
# 25                                            NaN      NaN        NaN
# 26                                            NaN      NaN        NaN
# 27                                      Etage : 3  Parking     Balcon
# 28    Chauffage : individuel électrique radiateur  Parking   Terrasse
# 29               Chauffage : électrique radiateur
# 30    Chauffage : individuel électrique,Etage : 2  Parking
# 31                               Chauffage : fuel
# 32  Chauffage : collectif gaz radiateur,Etage : 1  Parking
# 33                     Chauffage : fuel radiateur
# 34                                                 Parking   Terrasse
# 35                                                 Parking   Terrasse
# 36                                                 Parking   Terrasse
# 37                                                 Parking   Terrasse
#
#      publishedAt              reference
# 0            NaN                    NaN
# 1            NaN                    NaN
# 2            NaN                    NaN
# 3            NaN                    NaN
# 4            NaN                    NaN
# 5            NaN                    NaN
# 6            NaN                    NaN
# 7            NaN                    NaN
# 8            NaN                    NaN
# 9            NaN                    NaN
# 10           NaN                    NaN
# 11           NaN                    NaN
# 12           NaN                    NaN
# 13           NaN                    NaN
# 14           NaN                    NaN
# 15           NaN                    NaN
# 16           NaN                    NaN
# 17           NaN                    NaN
# 18           NaN                    NaN
# 19           NaN                    NaN
# 20           NaN                    NaN
# 21           NaN                    NaN
# 22           NaN                    NaN
# 23           NaN                    NaN
# 24           NaN                    NaN
# 25           NaN                    NaN
# 26           NaN                    NaN
# 27  1.763004e+09      ParuVendu 1840877
# 28  1.763004e+09      ParuVendu 1840631
# 29  1.763004e+09      ParuVendu 1838471
# 30  1.763090e+09      ParuVendu 1837235
# 31  1.763005e+09      ParuVendu 1832198
# 32  1.764128e+09      ParuVendu 1822571
# 33  1.763004e+09      ParuVendu 1819783
# 34  1.763445e+09   ParuVendu ZO_VVGPT50
# 35  1.763445e+09  ParuVendu ZO_VVGPT403
# 36  1.763445e+09  ParuVendu ZO_VVGPT502
# 37  1.763445e+09  ParuVendu ZO_VVGPT301

# %%
import math

def clean_nan(value):
    if isinstance(value, float) and math.isnan(value):
        return "NB"   # valeur par défaut quand c'est NaN
    return value

# %%
announcement_payloads = []
agency_payload = []
caracteristic_payload = []

for i in range(len(df_dico)):
    payload = {
        "url": clean_nan(paruvendu_data[0].iloc[i]),
        "ref": clean_nan(df_dico["reference"].iloc[i]),
        "title": clean_nan(df_dico["title"].iloc[i]),
        "description": clean_nan(df_dico["description"].iloc[i]),
        "price": clean_nan(df_dico["prix"].iloc[i]),
        "type": "NB", 
        "updated_at": df_dico["publishedAt"].iloc[i],
    }
    payload1 = {
        "name": clean_nan(df_dico["enseigneInfosvendeur"].iloc[i]),
    }
    payload2 = {
        "location": clean_nan(df_dico["location"].iloc[i]),
        "surface": clean_nan(df_dico["surf"].iloc[i]),
        "agencement": clean_nan(df_dico["agencement"].iloc[i]),
        "general": clean_nan(df_dico["general"].iloc[i]),
        "dependance": clean_nan(df_dico["dependance"].iloc[i]),
        "annexe": clean_nan(df_dico["annexe"].iloc[i]),
    }

    announcement_payloads.append(payload)
    agency_payload.append(payload1)
    caracteristic_payload.append(payload2)

# %%
if __name__ == "__main__":
    s = SessionLocal()
    for i in range(len(df_dico)):
        ann = create_announcement(
            s,
            announcement_data=announcement_payloads[i],
            announcer_data=agency_payload[i],
            estate_data=caracteristic_payload[i]
        )
    print("Created announcement id:", ann.id)
# Out:
# 2025-11-26 16:58:54,885 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:54,900 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:54,902 INFO sqlalchemy.engine.Engine [generated in 0.00210s] {'name_1': 'EFFICITY Sukhanakova Elena'}
# 2025-11-26 16:58:54,908 INFO sqlalchemy.engine.Engine INSERT INTO announcer (name, address, slogan, description, telephone, `yearMember`) VALUES (%(name)s, %(address)s, %(slogan)s, %(description)s, %(telephone)s, %(yearMember)s)
# 2025-11-26 16:58:54,909 INFO sqlalchemy.engine.Engine [generated in 0.00130s] {'name': 'EFFICITY Sukhanakova Elena', 'address': None, 'slogan': None, 'description': None, 'telephone': None, 'yearMember': None}
# 2025-11-26 16:58:54,916 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:54,917 INFO sqlalchemy.engine.Engine [generated in 0.00119s] {'ref_1': 'NB', 'agency_id_1': 1}
# 2025-11-26 16:58:54,924 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:54,925 INFO sqlalchemy.engine.Engine [generated in 0.00106s] {'ref': 'NB', 'title': 'Vente Appartement 1 pièce 28 m²', 'description': "Appartement 75013 - PARIS - BUTTE AUX CAILLES - STUDIO - 28m2 - RDC SUR COUR - AU CALME - EXPOSITION SUD - SÉCURISÉE - À REFAIRE - IDÉAL INVESTISSEUR ... (1366 characters truncated) ... ant moyen des Charges annuelles : 1272 euros Procédure sur le Syndicat des copropriétaires : non Statut du négociateur : agent commercial indépendant", 'price': '240 750', 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(nan), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1282974090A1KIVHAP000', 'type': 'NB', 'agency_id': 1}
# 2025-11-26 16:58:54,930 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:54,931 INFO sqlalchemy.engine.Engine [generated in 0.00097s] {'announcement_id_1': 1}
# 2025-11-26 16:58:54,936 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:54,937 INFO sqlalchemy.engine.Engine [generated in 0.00132s] {'announcement_id': 1, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Paris 13 (75013)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '28', 'agencement': 'NB'}
# 2025-11-26 16:58:54,940 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:54,944 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:54,946 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:54,947 INFO sqlalchemy.engine.Engine [cached since 0.04679s ago] {'name_1': "L'ADRESSE AUBERVILLIERS"}
# 2025-11-26 16:58:54,950 INFO sqlalchemy.engine.Engine INSERT INTO announcer (name, address, slogan, description, telephone, `yearMember`) VALUES (%(name)s, %(address)s, %(slogan)s, %(description)s, %(telephone)s, %(yearMember)s)
# 2025-11-26 16:58:54,951 INFO sqlalchemy.engine.Engine [cached since 0.04383s ago] {'name': "L'ADRESSE AUBERVILLIERS", 'address': None, 'slogan': None, 'description': None, 'telephone': None, 'yearMember': None}
# 2025-11-26 16:58:54,953 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:54,954 INFO sqlalchemy.engine.Engine [cached since 0.03874s ago] {'ref_1': 'NB', 'agency_id_1': 2}
# 2025-11-26 16:58:54,959 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:54,960 INFO sqlalchemy.engine.Engine [cached since 0.036s ago] {'ref': 'NB', 'title': 'Vente Appartement 1 pièce 28 m²', 'description': "Appartement 1 pièce Aubervilliers 27 m2 A vendre à Aubervilliers, découvrez ce studio charmant et lumineux, idéalement situé à proximité du centre-vi ... (1568 characters truncated) ... de la copropriété : 333 Montant moyen des Charges annuelles : 2040 euros Procédure sur le Syndicat des copropriétaires : NC Taxe foncière : 869 euros", 'price': '135 000', 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(nan), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1265798356A1KIVHAP000', 'type': 'NB', 'agency_id': 2}
# 2025-11-26 16:58:54,963 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:54,964 INFO sqlalchemy.engine.Engine [cached since 0.03415s ago] {'announcement_id_1': 2}
# 2025-11-26 16:58:54,966 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:54,967 INFO sqlalchemy.engine.Engine [cached since 0.03123s ago] {'announcement_id': 2, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Aubervilliers (93300)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '28', 'agencement': 'NB'}
# 2025-11-26 16:58:54,969 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:54,972 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:54,974 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:54,975 INFO sqlalchemy.engine.Engine [cached since 0.07493s ago] {'name_1': "L'ADRESSE AUBERVILLIERS"}
# 2025-11-26 16:58:54,978 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:54,979 INFO sqlalchemy.engine.Engine [cached since 0.06295s ago] {'ref_1': 'NB', 'agency_id_1': 2}
# 2025-11-26 16:58:54,982 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:54,983 INFO sqlalchemy.engine.Engine [cached since 0.05322s ago] {'announcement_id_1': 2}
# 2025-11-26 16:58:54,987 INFO sqlalchemy.engine.Engine UPDATE announcements SET title=%(title)s, description=%(description)s, price=%(price)s, updated_at=%(updated_at)s, url=%(url)s, type=%(type)s WHERE announcements.id = %(announcements_id)s
# 2025-11-26 16:58:54,988 INFO sqlalchemy.engine.Engine [generated in 0.00116s] {'title': 'Vente Appartement 2 pièces 42 m²', 'description': 'Appartement Pierrefitte Sur Seine 2 pièces 42 m2 A vendre à Pierrefitte-sur-Seine, un appartement niché au sixième étage d\'une résidence sécurisée,  ... (1457 characters truncated) ... de la copropriété : 82 Montant moyen des Charges annuelles : 2400 euros Procédure sur le Syndicat des copropriétaires : NC Taxe foncière : 1100 euros', 'price': '137 800', 'updated_at': np.float64(nan), 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1275249674A1KIVHAP000', 'type': 'NB', 'announcements_id': 2}
# 2025-11-26 16:58:54,992 INFO sqlalchemy.engine.Engine UPDATE estate SET location=%(location)s, surface=%(surface)s WHERE estate.id = %(estate_id)s
# 2025-11-26 16:58:54,993 INFO sqlalchemy.engine.Engine [generated in 0.00093s] {'location': 'Saint denis (93200)', 'surface': '42', 'estate_id': 2}
# 2025-11-26 16:58:54,995 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:54,998 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:54,999 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,000 INFO sqlalchemy.engine.Engine [cached since 0.09992s ago] {'name_1': 'HAG IMMOBILIER'}
# 2025-11-26 16:58:55,002 INFO sqlalchemy.engine.Engine INSERT INTO announcer (name, address, slogan, description, telephone, `yearMember`) VALUES (%(name)s, %(address)s, %(slogan)s, %(description)s, %(telephone)s, %(yearMember)s)
# 2025-11-26 16:58:55,003 INFO sqlalchemy.engine.Engine [cached since 0.096s ago] {'name': 'HAG IMMOBILIER', 'address': None, 'slogan': None, 'description': None, 'telephone': None, 'yearMember': None}
# 2025-11-26 16:58:55,006 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,007 INFO sqlalchemy.engine.Engine [cached since 0.09145s ago] {'ref_1': 'NB', 'agency_id_1': 3}
# 2025-11-26 16:58:55,011 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:55,012 INFO sqlalchemy.engine.Engine [cached since 0.08825s ago] {'ref': 'NB', 'title': 'Vente Appartement 1 pièce 24 m²', 'description': 'APPARTEMENT POISSY - 1 pièce(s) - 24.46m2 IDÉAL INVESTISSEUR - Secteur Mairie, Studio meublé VENDU LOUE dans une jolie résidence comprenant entrée, p ... (447 characters truncated) ...  650 euros Procédure sur le Syndicat des copropriétaires : NC Détail sur la procédure en cours : Pas de procédure en cours Taxe foncière : 1009 euros', 'price': '123 000', 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(nan), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1280770411A1KIVHAP000', 'type': 'NB', 'agency_id': 3}
# 2025-11-26 16:58:55,015 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,016 INFO sqlalchemy.engine.Engine [cached since 0.0862s ago] {'announcement_id_1': 3}
# 2025-11-26 16:58:55,019 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:55,020 INFO sqlalchemy.engine.Engine [cached since 0.08401s ago] {'announcement_id': 3, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Carrieres sous poissy (78955)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '24', 'agencement': 'NB'}
# 2025-11-26 16:58:55,022 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,026 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,027 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,028 INFO sqlalchemy.engine.Engine [cached since 0.1278s ago] {'name_1': 'MAXIHOME'}
# 2025-11-26 16:58:55,030 INFO sqlalchemy.engine.Engine INSERT INTO announcer (name, address, slogan, description, telephone, `yearMember`) VALUES (%(name)s, %(address)s, %(slogan)s, %(description)s, %(telephone)s, %(yearMember)s)
# 2025-11-26 16:58:55,031 INFO sqlalchemy.engine.Engine [cached since 0.1232s ago] {'name': 'MAXIHOME', 'address': None, 'slogan': None, 'description': None, 'telephone': None, 'yearMember': None}
# 2025-11-26 16:58:55,033 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,034 INFO sqlalchemy.engine.Engine [cached since 0.1179s ago] {'ref_1': 'NB', 'agency_id_1': 4}
# 2025-11-26 16:58:55,036 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:55,037 INFO sqlalchemy.engine.Engine [cached since 0.1129s ago] {'ref': 'NB', 'title': 'Vente Appartement 2 pièces 52 m²', 'description': "Vente Appartemnt Au c?ur des vallées à proximité de la gare et des commerces, découvrez cet appartement calme et lumineux au sein d'une petite coprop ... (730 characters truncated) ... 61 Honoraires à la charge du Vendeur Bien En copropriété : OUI Nombre de lots de la copropriété : 13 Montant moyen des Charges annuelles : 1739 euros", 'price': '435 000', 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(nan), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1286219307A1KIVHAP000', 'type': 'NB', 'agency_id': 4}
# 2025-11-26 16:58:55,041 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,042 INFO sqlalchemy.engine.Engine [cached since 0.1122s ago] {'announcement_id_1': 4}
# 2025-11-26 16:58:55,045 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:55,046 INFO sqlalchemy.engine.Engine [cached since 0.1101s ago] {'announcement_id': 4, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'La garenne-colombes (92250)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '52', 'agencement': 'NB'}
# 2025-11-26 16:58:55,048 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,052 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,053 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,054 INFO sqlalchemy.engine.Engine [cached since 0.1543s ago] {'name_1': 'HAG IMMOBILIER'}
# 2025-11-26 16:58:55,058 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,058 INFO sqlalchemy.engine.Engine [cached since 0.1426s ago] {'ref_1': 'NB', 'agency_id_1': 3}
# 2025-11-26 16:58:55,062 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,063 INFO sqlalchemy.engine.Engine [cached since 0.1332s ago] {'announcement_id_1': 3}
# 2025-11-26 16:58:55,066 INFO sqlalchemy.engine.Engine UPDATE announcements SET title=%(title)s, description=%(description)s, price=%(price)s, updated_at=%(updated_at)s, url=%(url)s, type=%(type)s WHERE announcements.id = %(announcements_id)s
# 2025-11-26 16:58:55,067 INFO sqlalchemy.engine.Engine [cached since 0.08004s ago] {'title': 'Vente Appartement 1 pièce 30 m²', 'description': "studio vendu loue Dans un quartier calme de Carrières-Sous-Poissy, Studio de 30m². Cet appartement ce compose d'un séjour, une cuisine équipée et une ... (568 characters truncated) ... 1000 euros Procédure sur le Syndicat des copropriétaires : NC Détail sur la procédure en cours : Pas de procédure en cours Taxe foncière : 1073 euros", 'price': '130 000', 'updated_at': np.float64(nan), 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1284377599A1KIVHAP000', 'type': 'NB', 'announcements_id': 3}
# 2025-11-26 16:58:55,070 INFO sqlalchemy.engine.Engine UPDATE estate SET surface=%(surface)s WHERE estate.id = %(estate_id)s
# 2025-11-26 16:58:55,071 INFO sqlalchemy.engine.Engine [generated in 0.00092s] {'surface': '30', 'estate_id': 3}
# 2025-11-26 16:58:55,073 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,076 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,077 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,078 INFO sqlalchemy.engine.Engine [cached since 0.1779s ago] {'name_1': 'STEPHAN CEREZO IMMOBILIER'}
# 2025-11-26 16:58:55,081 INFO sqlalchemy.engine.Engine INSERT INTO announcer (name, address, slogan, description, telephone, `yearMember`) VALUES (%(name)s, %(address)s, %(slogan)s, %(description)s, %(telephone)s, %(yearMember)s)
# 2025-11-26 16:58:55,082 INFO sqlalchemy.engine.Engine [cached since 0.1746s ago] {'name': 'STEPHAN CEREZO IMMOBILIER', 'address': None, 'slogan': None, 'description': None, 'telephone': None, 'yearMember': None}
# 2025-11-26 16:58:55,084 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,085 INFO sqlalchemy.engine.Engine [cached since 0.1693s ago] {'ref_1': 'NB', 'agency_id_1': 5}
# 2025-11-26 16:58:55,088 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:55,089 INFO sqlalchemy.engine.Engine [cached since 0.1654s ago] {'ref': 'NB', 'title': 'Vente Maison 6 pièces 160 m²', 'description': "MAISON BEAU JARDIN PISCINE COUVERTE ET SOUS-SOL TOTAL Au centre d'un charmant village au calme et à quelques minutes de tous commerces, écoles et com ... (1307 characters truncated) ... ne : Amenagée Numéro de mandat : 434 Honoraires à la charge de : Vendeur Bien En copropriété : Non Procédure sur le Syndicat des copropriétaires : NC", 'price': '415 000', 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(nan), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/vente/maison/1282509886A1KIVHMN000', 'type': 'NB', 'agency_id': 5}
# 2025-11-26 16:58:55,092 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,093 INFO sqlalchemy.engine.Engine [cached since 0.1632s ago] {'announcement_id_1': 5}
# 2025-11-26 16:58:55,096 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:55,097 INFO sqlalchemy.engine.Engine [cached since 0.161s ago] {'announcement_id': 5, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Adainville (78113)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '160', 'agencement': 'NB'}
# 2025-11-26 16:58:55,099 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,103 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,104 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,105 INFO sqlalchemy.engine.Engine [cached since 0.2047s ago] {'name_1': 'STEPHAN CEREZO IMMOBILIER'}
# 2025-11-26 16:58:55,107 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,108 INFO sqlalchemy.engine.Engine [cached since 0.1926s ago] {'ref_1': 'NB', 'agency_id_1': 5}
# 2025-11-26 16:58:55,112 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,113 INFO sqlalchemy.engine.Engine [cached since 0.1831s ago] {'announcement_id_1': 5}
# 2025-11-26 16:58:55,116 INFO sqlalchemy.engine.Engine UPDATE announcements SET title=%(title)s, description=%(description)s, price=%(price)s, updated_at=%(updated_at)s, url=%(url)s, type=%(type)s WHERE announcements.id = %(announcements_id)s
# 2025-11-26 16:58:55,118 INFO sqlalchemy.engine.Engine [cached since 0.1304s ago] {'title': 'Vente Maison 8 pièces 190 m²', 'description': "Maison Poigny La Foret 8 pièce(s) 190 m2 Dans charmant village entre Montfort l(Amaury et Rambouillet. Jolie maison de village en pierre et petites t ... (629 characters truncated) ... e (mode) : PompeChaleur Cuisine : AmenageeEquipee Numéro de mandat : 449 Bien En copropriété : Non Procédure sur le Syndicat des copropriétaires : NC", 'price': '598 000', 'updated_at': np.float64(nan), 'url': 'https://www.paruvendu.fr/immobilier/vente/maison/1284781407A1KIVHMN000', 'type': 'NB', 'announcements_id': 5}
# 2025-11-26 16:58:55,120 INFO sqlalchemy.engine.Engine UPDATE estate SET location=%(location)s, surface=%(surface)s WHERE estate.id = %(estate_id)s
# 2025-11-26 16:58:55,120 INFO sqlalchemy.engine.Engine [cached since 0.1283s ago] {'location': 'Poigny la foret (78125)', 'surface': '190', 'estate_id': 5}
# 2025-11-26 16:58:55,123 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,129 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,131 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,132 INFO sqlalchemy.engine.Engine [cached since 0.2322s ago] {'name_1': ''}
# 2025-11-26 16:58:55,136 INFO sqlalchemy.engine.Engine INSERT INTO announcer (name, address, slogan, description, telephone, `yearMember`) VALUES (%(name)s, %(address)s, %(slogan)s, %(description)s, %(telephone)s, %(yearMember)s)
# 2025-11-26 16:58:55,138 INFO sqlalchemy.engine.Engine [cached since 0.2307s ago] {'name': '', 'address': None, 'slogan': None, 'description': None, 'telephone': None, 'yearMember': None}
# 2025-11-26 16:58:55,141 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,142 INFO sqlalchemy.engine.Engine [cached since 0.226s ago] {'ref_1': 'NB', 'agency_id_1': 6}
# 2025-11-26 16:58:55,146 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:55,148 INFO sqlalchemy.engine.Engine [cached since 0.2238s ago] {'ref': 'NB', 'title': '', 'description': "EXCLUSIVITE - Propriété pleine de charme avec piscine sur les rives de la Seine Dans le charmant village de Bennecourt où Zola, Cézanne et Monet y on ... (1909 characters truncated) ... erphone : oui Numéro de mandat : 453 Honoraires à la charge de : Vendeur Bien En copropriété : Non Procédure sur le Syndicat des copropriétaires : NC", 'price': None, 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(nan), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/prestige/maison/1285973960A1KIVHMN000', 'type': 'NB', 'agency_id': 6}
# 2025-11-26 16:58:55,152 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,153 INFO sqlalchemy.engine.Engine [cached since 0.2233s ago] {'announcement_id_1': 6}
# 2025-11-26 16:58:55,157 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:55,159 INFO sqlalchemy.engine.Engine [cached since 0.2228s ago] {'announcement_id': 6, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Bennecourt (78270)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '208', 'agencement': 'NB'}
# 2025-11-26 16:58:55,163 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,167 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,168 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,169 INFO sqlalchemy.engine.Engine [cached since 0.2692s ago] {'name_1': 'STEPHAN CEREZO IMMOBILIER'}
# 2025-11-26 16:58:55,172 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,173 INFO sqlalchemy.engine.Engine [cached since 0.2572s ago] {'ref_1': 'NB', 'agency_id_1': 5}
# 2025-11-26 16:58:55,176 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,177 INFO sqlalchemy.engine.Engine [cached since 0.2476s ago] {'announcement_id_1': 5}
# 2025-11-26 16:58:55,180 INFO sqlalchemy.engine.Engine UPDATE announcements SET title=%(title)s, description=%(description)s, price=%(price)s, updated_at=%(updated_at)s, url=%(url)s, type=%(type)s WHERE announcements.id = %(announcements_id)s
# 2025-11-26 16:58:55,181 INFO sqlalchemy.engine.Engine [cached since 0.1939s ago] {'title': 'Vente Maison 5 pièces 163 m²', 'description': "Maison 5 pièce(s) 163 m2 Dans village entre Gambais et Houdan, maison récente de plain-pied comprenant hall d'entée, double séjour avec cuisine aména ... (142 characters truncated) ... ce terrain : 1250 Cuisine : Amenagée Honoraires à la charge de : Vendeur Bien En copropriété : Non Procédure sur le Syndicat des copropriétaires : NC", 'price': '400 000', 'updated_at': np.float64(nan), 'url': 'https://www.paruvendu.fr/immobilier/vente/maison/1282999454A1KIVHMN000', 'type': 'NB', 'announcements_id': 5}
# 2025-11-26 16:58:55,184 INFO sqlalchemy.engine.Engine UPDATE estate SET location=%(location)s, surface=%(surface)s WHERE estate.id = %(estate_id)s
# 2025-11-26 16:58:55,185 INFO sqlalchemy.engine.Engine [cached since 0.1931s ago] {'location': 'Bourdonne (78113)', 'surface': '163', 'estate_id': 5}
# 2025-11-26 16:58:55,187 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,191 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,192 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,193 INFO sqlalchemy.engine.Engine [cached since 0.2931s ago] {'name_1': 'ADM IMMOBILIER'}
# 2025-11-26 16:58:55,196 INFO sqlalchemy.engine.Engine INSERT INTO announcer (name, address, slogan, description, telephone, `yearMember`) VALUES (%(name)s, %(address)s, %(slogan)s, %(description)s, %(telephone)s, %(yearMember)s)
# 2025-11-26 16:58:55,198 INFO sqlalchemy.engine.Engine [cached since 0.2906s ago] {'name': 'ADM IMMOBILIER', 'address': None, 'slogan': None, 'description': None, 'telephone': None, 'yearMember': None}
# 2025-11-26 16:58:55,202 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,203 INFO sqlalchemy.engine.Engine [cached since 0.2875s ago] {'ref_1': 'NB', 'agency_id_1': 7}
# 2025-11-26 16:58:55,208 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:55,209 INFO sqlalchemy.engine.Engine [cached since 0.2847s ago] {'ref': 'NB', 'title': 'Vente Appartement 3 pièces 60 m²', 'description': "À vendre Bel appartement T3 avec balcon et vue dégagée Quartier Foch En exclusivité chez ADM IMMOBILIER : Situé au 12ème étage avec ascenseur d'une r ... (1035 characters truncated) ... age : COLLECTIF Balcon : 1 Nombre de wc : 1 Cave : 1 Honoraires à charge du Vendeur Nom du négociateur : COUILLY AGENCE DE Taxe foncière : 1296 euros", 'price': '164 000', 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(nan), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1286524608A1KIVHAP000', 'type': 'NB', 'agency_id': 7}
# 2025-11-26 16:58:55,212 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,214 INFO sqlalchemy.engine.Engine [cached since 0.2838s ago] {'announcement_id_1': 7}
# 2025-11-26 16:58:55,216 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:55,217 INFO sqlalchemy.engine.Engine [cached since 0.2813s ago] {'announcement_id': 7, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Meaux (77100)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '60', 'agencement': 'NB'}
# 2025-11-26 16:58:55,220 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,223 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,224 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,226 INFO sqlalchemy.engine.Engine [cached since 0.3258s ago] {'name_1': 'ADM IMMOBILIER'}
# 2025-11-26 16:58:55,229 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,230 INFO sqlalchemy.engine.Engine [cached since 0.3147s ago] {'ref_1': 'NB', 'agency_id_1': 7}
# 2025-11-26 16:58:55,233 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,235 INFO sqlalchemy.engine.Engine [cached since 0.3048s ago] {'announcement_id_1': 7}
# 2025-11-26 16:58:55,238 INFO sqlalchemy.engine.Engine UPDATE announcements SET title=%(title)s, description=%(description)s, price=%(price)s, updated_at=%(updated_at)s, url=%(url)s, type=%(type)s WHERE announcements.id = %(announcements_id)s
# 2025-11-26 16:58:55,239 INFO sqlalchemy.engine.Engine [cached since 0.2515s ago] {'title': 'Vente Maison 5 pièces 115 m²', 'description': "maison Meulière à Saint Cyr sur Morin ADM IMMOBILIER vous présente en exclusivité cette magnifique meulière qui allie charme authentique et praticité ... (1180 characters truncated) ...  : INDIVIDUEL Nombre de wc : 2 Nombre de parking : 1 Honoraires à charge du Vendeur Nom du négociateur : COUILLY AGENCE DE Taxe foncière : 1389 euros", 'price': '260 000', 'updated_at': np.float64(nan), 'url': 'https://www.paruvendu.fr/immobilier/vente/maison/1283970845A1KIVHMN000', 'type': 'NB', 'announcements_id': 7}
# 2025-11-26 16:58:55,241 INFO sqlalchemy.engine.Engine UPDATE estate SET location=%(location)s, surface=%(surface)s WHERE estate.id = %(estate_id)s
# 2025-11-26 16:58:55,242 INFO sqlalchemy.engine.Engine [cached since 0.2503s ago] {'location': 'St cyr sur morin (77750)', 'surface': '115', 'estate_id': 7}
# 2025-11-26 16:58:55,245 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,248 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,249 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,250 INFO sqlalchemy.engine.Engine [cached since 0.3501s ago] {'name_1': ''}
# 2025-11-26 16:58:55,253 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# ...
# 2025-11-26 16:58:55,856 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,857 INFO sqlalchemy.engine.Engine [cached since 0.9266s ago] {'announcement_id_1': 17}
# 2025-11-26 16:58:55,860 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:55,861 INFO sqlalchemy.engine.Engine [cached since 0.9247s ago] {'announcement_id': 17, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Viry chatillon (91170)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '91', 'agencement': '4 chambres'}
# 2025-11-26 16:58:55,863 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,866 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,867 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,868 INFO sqlalchemy.engine.Engine [cached since 0.9682s ago] {'name_1': 'UTOPIA Paris - Bordeau - PACA'}
# 2025-11-26 16:58:55,870 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,871 INFO sqlalchemy.engine.Engine [cached since 0.9554s ago] {'ref_1': 'ParuVendu ZO_VVGPT403', 'agency_id_1': 16}
# 2025-11-26 16:58:55,875 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:55,876 INFO sqlalchemy.engine.Engine [cached since 0.952s ago] {'ref': 'ParuVendu ZO_VVGPT403', 'title': 'Vente Appartement 4 pièces 85 m²', 'description': "T4 Lumineux Grande Terrasse Vu Seine Offrez-vous un appartement à Viry-Châtillon, au sein d'une résidence contemporaine et à taille humaine. Située à ... (491 characters truncated) ... gible au Prêt à Taux Zéro (PTZ) Résidence neuve livrée prochainement Plus d'informations : – Contact 7j/7 (Photos et aménagements à titre indicatif.)", 'price': '364 000', 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(1763445300.0), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1286764633A1KIVHAP000', 'type': 'NB', 'agency_id': 16}
# 2025-11-26 16:58:55,881 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,882 INFO sqlalchemy.engine.Engine [cached since 0.9521s ago] {'announcement_id_1': 18}
# 2025-11-26 16:58:55,885 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:55,886 INFO sqlalchemy.engine.Engine [cached since 0.9499s ago] {'announcement_id': 18, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Viry chatillon (91170)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '85', 'agencement': '3 chambres'}
# 2025-11-26 16:58:55,889 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,894 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,896 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,898 INFO sqlalchemy.engine.Engine [cached since 0.9985s ago] {'name_1': 'UTOPIA Paris - Bordeau - PACA'}
# 2025-11-26 16:58:55,901 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,902 INFO sqlalchemy.engine.Engine [cached since 0.9864s ago] {'ref_1': 'ParuVendu ZO_VVGPT502', 'agency_id_1': 16}
# 2025-11-26 16:58:55,906 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:55,907 INFO sqlalchemy.engine.Engine [cached since 0.983s ago] {'ref': 'ParuVendu ZO_VVGPT502', 'title': 'Vente Appartement 5 pièces 102 m²', 'description': "T5 Terrasse VU SEINE de 67 m2 ! Verdoyant Offrez-vous un appartement à Viry-Châtillon, au sein d'une résidence contemporaine et à taille humaine. Sit ... (496 characters truncated) ... gible au Prêt à Taux Zéro (PTZ) Résidence neuve livrée prochainement Plus d'informations : – Contact 7j/7 (Photos et aménagements à titre indicatif.)", 'price': '475 000', 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(1763445300.0), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1286764639A1KIVHAP000', 'type': 'NB', 'agency_id': 16}
# 2025-11-26 16:58:55,912 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,913 INFO sqlalchemy.engine.Engine [cached since 0.9832s ago] {'announcement_id_1': 19}
# 2025-11-26 16:58:55,917 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:55,918 INFO sqlalchemy.engine.Engine [cached since 0.9819s ago] {'announcement_id': 19, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Viry chatillon (91170)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '102', 'agencement': '4 chambres'}
# 2025-11-26 16:58:55,919 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,922 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,923 INFO sqlalchemy.engine.Engine SELECT announcer.id, announcer.name, announcer.address, announcer.slogan, announcer.description, announcer.telephone, announcer.`yearMember`
# FROM announcer
# WHERE announcer.name = %(name_1)s
# 2025-11-26 16:58:55,924 INFO sqlalchemy.engine.Engine [cached since 1.024s ago] {'name_1': 'UTOPIA Paris - Bordeau - PACA'}
# 2025-11-26 16:58:55,927 INFO sqlalchemy.engine.Engine SELECT announcements.id, announcements.ref, announcements.title, announcements.description, announcements.price, announcements.price_per_meter, announcements.publish_at, announcements.exclusive, announcements.updated_at, announcements.dpe, announcements.url, announcements.type, announcements.agency_id, announcer_1.id AS id_1, announcer_1.name, announcer_1.address, announcer_1.slogan, announcer_1.description AS description_1, announcer_1.telephone, announcer_1.`yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.ref = %(ref_1)s AND announcements.agency_id = %(agency_id_1)s
# 2025-11-26 16:58:55,927 INFO sqlalchemy.engine.Engine [cached since 1.012s ago] {'ref_1': 'ParuVendu ZO_VVGPT301', 'agency_id_1': 16}
# 2025-11-26 16:58:55,930 INFO sqlalchemy.engine.Engine INSERT INTO announcements (ref, title, description, price, price_per_meter, publish_at, exclusive, updated_at, dpe, url, type, agency_id) VALUES (%(ref)s, %(title)s, %(description)s, %(price)s, %(price_per_meter)s, %(publish_at)s, %(exclusive)s, %(updated_at)s, %(dpe)s, %(url)s, %(type)s, %(agency_id)s)
# 2025-11-26 16:58:55,931 INFO sqlalchemy.engine.Engine [cached since 1.007s ago] {'ref': 'ParuVendu ZO_VVGPT301', 'title': 'Vente Appartement 3 pièces 60 m²', 'description': "T3 Bord de Seine & bien agencer Offrez-vous un appartement neuf à Viry-Châtillon, au sein d'une résidence contemporaine et à taille humaine. Située à ... (489 characters truncated) ... gible au Prêt à Taux Zéro (PTZ) Résidence neuve livrée prochainement Plus d'informations : – Contact 7j/7 (Photos et aménagements à titre indicatif.)", 'price': '248 000', 'price_per_meter': None, 'publish_at': None, 'exclusive': None, 'updated_at': np.float64(1763445300.0), 'dpe': None, 'url': 'https://www.paruvendu.fr/immobilier/vente/appartement/1286764619A1KIVHAP000', 'type': 'NB', 'agency_id': 16}
# 2025-11-26 16:58:55,936 INFO sqlalchemy.engine.Engine SELECT estate.id, estate.announcement_id, estate.nb_rooms, estate.nb_bedrooms, estate.location, estate.parking_garage, estate.garden, estate.balcony_terrace, estate.annexes, estate.access, estate.arrangement, estate.dependence, estate.outside, estate.connectivity_index, estate.fiber_eligibility_rate, estate.general_information, estate.surface, estate.agencement
# FROM estate
# WHERE estate.announcement_id = %(announcement_id_1)s
# 2025-11-26 16:58:55,937 INFO sqlalchemy.engine.Engine [cached since 1.008s ago] {'announcement_id_1': 20}
# 2025-11-26 16:58:55,940 INFO sqlalchemy.engine.Engine INSERT INTO estate (announcement_id, nb_rooms, nb_bedrooms, location, parking_garage, garden, balcony_terrace, annexes, access, arrangement, dependence, outside, connectivity_index, fiber_eligibility_rate, general_information, surface, agencement) VALUES (%(announcement_id)s, %(nb_rooms)s, %(nb_bedrooms)s, %(location)s, %(parking_garage)s, %(garden)s, %(balcony_terrace)s, %(annexes)s, %(access)s, %(arrangement)s, %(dependence)s, %(outside)s, %(connectivity_index)s, %(fiber_eligibility_rate)s, %(general_information)s, %(surface)s, %(agencement)s)
# 2025-11-26 16:58:55,941 INFO sqlalchemy.engine.Engine [cached since 1.005s ago] {'announcement_id': 20, 'nb_rooms': None, 'nb_bedrooms': None, 'location': 'Viry chatillon (91170)', 'parking_garage': None, 'garden': None, 'balcony_terrace': None, 'annexes': None, 'access': None, 'arrangement': None, 'dependence': None, 'outside': None, 'connectivity_index': None, 'fiber_eligibility_rate': None, 'general_information': None, 'surface': '60', 'agencement': '2 chambres'}
# 2025-11-26 16:58:55,943 INFO sqlalchemy.engine.Engine COMMIT
# 2025-11-26 16:58:55,947 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-26 16:58:55,953 INFO sqlalchemy.engine.Engine SELECT announcements.id AS announcements_id, announcements.ref AS announcements_ref, announcements.title AS announcements_title, announcements.description AS announcements_description, announcements.price AS announcements_price, announcements.price_per_meter AS announcements_price_per_meter, announcements.publish_at AS announcements_publish_at, announcements.exclusive AS announcements_exclusive, announcements.updated_at AS announcements_updated_at, announcements.dpe AS announcements_dpe, announcements.url AS announcements_url, announcements.type AS announcements_type, announcements.agency_id AS announcements_agency_id, announcer_1.id AS announcer_1_id, announcer_1.name AS announcer_1_name, announcer_1.address AS announcer_1_address, announcer_1.slogan AS announcer_1_slogan, announcer_1.description AS announcer_1_description, announcer_1.telephone AS announcer_1_telephone, announcer_1.`yearMember` AS `announcer_1_yearMember`
# FROM announcements LEFT OUTER JOIN announcer AS announcer_1 ON announcer_1.id = announcements.agency_id
# WHERE announcements.id = %(pk_1)s
# 2025-11-26 16:58:55,955 INFO sqlalchemy.engine.Engine [generated in 0.00166s] {'pk_1': 20}
# Created announcement id: 20
